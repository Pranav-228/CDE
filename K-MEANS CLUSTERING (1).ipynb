# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## NAME : PRANAV SUDHIR PATIL
# ## DOMAIN : MACHINE LEARNING
# ## BATCH : 3
# ## MENTORED BY : SHIKKY MA'AM
#
# ## PROJECT TOPIC : K-MEANS CLUSTERING

# %%
#Importing libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
#Generate our dataset
dataset = make_blobs(n_samples = 15 , centers = 2 , n_features = 2 , cluster_std = 1.6 , random_state = 50)

# %%
points = dataset[0]

# %%
print(dataset)
# Out:
# (array([[-5.52085089, -1.8364165 ],
#        [ 5.19455346, -3.85790517],
#        [-5.34054071,  0.6640499 ],
#        [-2.15963524, -7.56230415],
#        [-3.13818631,  0.06805212],
#        [-5.13014815, -0.96891106],
#        [ 2.15114671, -6.20110934],
#        [ 0.09021892, -4.24988128],
#        [-1.70400879, -2.88008464],
#        [ 1.00681205, -5.97364221],
#        [-5.55009665, -2.3305459 ],
#        [-1.35671783, -3.72590953],
#        [-7.08089219, -1.2951176 ],
#        [-4.66727117, -1.61665082],
#        [ 0.09417313, -4.05882797]]), array([1, 0, 1, 0, 1, 1, 0, 0, 0, 0, 1, 0, 1, 1, 0]))

# %%
#Import KMeans algorithm 
from sklearn.cluster import KMeans

# %%
#Create a KMeans object
kmeans=KMeans(n_clusters = 2)

# %%
kmeans.fit(points)
# Out:
# KMeans(n_clusters=2)

# %%
plt.scatter(dataset[0][:,0],dataset[0][:,1]);

# %%
clusters = kmeans.cluster_centers_

# %%
print(clusters)
# Out:
# [[-5.20399801 -1.04507712]
#  [ 0.4145678  -4.81370804]]

# %%
y_km=kmeans.fit_predict(points)

# %%
y_km
# Out:
# array([0, 1, 0, 1, 0, 0, 1, 1, 1, 1, 0, 1, 0, 0, 1])

# %%
points
# Out:
# array([[-5.52085089, -1.8364165 ],
#        [ 5.19455346, -3.85790517],
#        [-5.34054071,  0.6640499 ],
#        [-2.15963524, -7.56230415],
#        [-3.13818631,  0.06805212],
#        [-5.13014815, -0.96891106],
#        [ 2.15114671, -6.20110934],
#        [ 0.09021892, -4.24988128],
#        [-1.70400879, -2.88008464],
#        [ 1.00681205, -5.97364221],
#        [-5.55009665, -2.3305459 ],
#        [-1.35671783, -3.72590953],
#        [-7.08089219, -1.2951176 ],
#        [-4.66727117, -1.61665082],
#        [ 0.09417313, -4.05882797]])

# %%
plt.scatter(points[y_km == 0,0] , points[y_km == 0,1] , s = 50 , color = 'red');

# %%
plt.scatter(points[y_km == 0,0] , points[y_km == 0,1] , s = 50 , color = 'red');
plt.scatter(points[y_km == 1,0] , points[y_km == 1,1] , s = 50 , color = 'green');

# %%
plt.scatter(points[y_km == 0,0] , points[y_km == 0,1] , s = 50 , color = 'red');
plt.scatter(points[y_km == 1,0] , points[y_km == 1,1] , s = 50 , color = 'green');


plt.scatter(clusters[0][0] , clusters[0][1] , s=200 , marker = '*' , color='black');
plt.scatter(clusters[1][0] , clusters[1][1] , s=200 , marker = '*' , color='blue');
